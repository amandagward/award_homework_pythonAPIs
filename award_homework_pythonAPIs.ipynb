# %%
# Dependencies
import matplotlib.pyplot as plt
from citipy import citipy
import pandas as pd
import numpy as np
import requests
import time
import json
from config import api_key
output_data_file = "output_data/cities.csv"
lat_range = (-90, 90)
lng_range = (-180, 180)
import gmaps
gmaps.configure(api_key=api_key)

# %%
# Generate Cities List

# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 607

# %%
# Perform API Calls

# Perform a weather check on each city using a series of successive API calls
# Include a print log of each city as it'sbeing processed (with the city number and city name).

# Get Weather Data
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={api_key}&units={units}&q="

weather_response = requests.get(query_url + city)
weather_json = weather_response.json()
print(json.dumps(weather_json, indent=4))
# Out:
# {
#     "coord": {
#         "lon": -56.15,
#         "lat": 72.79
#     },
#     "weather": [
#         {
#             "id": 802,
#             "main": "Clouds",
#             "description": "scattered clouds",
#             "icon": "03d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 43.15,
#         "pressure": 1013.55,
#         "humidity": 77,
#         "temp_min": 43.15,
#         "temp_max": 43.15,
#         "sea_level": 1013.55,
#         "grnd_level": 1013.05
#     },
#     "wind": {
#         "speed": 24.9,
#         "deg": 349.596
#     },
#     "clouds": {
#         "all": 42
#     },
#     "dt": 1562723026,
#     "sys": {
#         "message": 0.0071,
#         "country": "GL",
#         "sunrise": 0,
#         "sunset": 0
#     },
#     "timezone": -7200,
#     "id": 3418910,
#     "name": "Upernavik",
#     "cod": 200
# }

# %%
# Include a print log of each city as it'sbeing processed (with the city number and city name)

print(requests.get(query_url + city))
# Out:
# <Response [200]>

# %%
# Set Up Lists to Hold Reponse Info

city_name = []
country = []
date = []
latitude = []
longitude = []
max_temperature = []
humidity = []
cloudiness = []
wind_speed = []

# Processing Record Counter Starting a 1
processing_record = 1

# Print Starting Log Statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

# Loop Through List of Cities & Perform a Request for Data on Each
for city in cities:

# Exception Handling
    try:
        response = requests.get(query_url + city).json()
        city_name.append(response["name"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        latitude.append(response["coord"]["lat"])
        longitude.append(response["coord"]["lon"])
        max_temperature.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {processing_record} | {city_record}")
        
        # Increase Processing Record Counter by 1 For Each Loop
        processing_record += 1
        
    except:
        print("City not found. Skipping...") 
    continue

# Print Ending Log Statement
print(f"-------------------------------")
print(f"Data Retrieval Complete")
print(f"-------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | Lagoa
# Processing Record 2 | Barrow
# City not found. Skipping...
# Processing Record 3 | Airai
# Processing Record 4 | Sao Filipe
# Processing Record 5 | Bambous Virieux
# Processing Record 6 | Dali
# Processing Record 7 | Rikitea
# City not found. Skipping...
# Processing Record 8 | New Norfolk
# Processing Record 9 | Hearst
# City not found. Skipping...
# Processing Record 10 | Puerto Ayora
# Processing Record 11 | Punta Arenas
# Processing Record 12 | Lima
# Processing Record 13 | Avarua
# Processing Record 14 | Yellowknife
# Processing Record 15 | Bluff
# Processing Record 16 | Luanda
# Processing Record 17 | Sabzevar
# Processing Record 18 | Ushuaia
# City not found. Skipping...
# Processing Record 19 | Albany
# Processing Record 20 | Inhambane
# Processing Record 21 | Castro
# Processing Record 22 | Mataura
# Processing Record 23 | Los Llanos de Aridane
# Processing Record 24 | Nanortalik
# Processing Record 25 | Coquimbo
# Processing Record 26 | Ambilobe
# Processing Record 27 | Fare
# Processing Record 28 | Cayenne
# Processing Record 29 | Baft
# Processing Record 30 | Hermanus
# Processing Record 31 | Tasiilaq
# Processing Record 32 | Provideniya
# Processing Record 33 | Busselton
# Processing Record 34 | Hithadhoo
# Processing Record 35 | Buraydah
# Processing Record 36 | Lerwick
# Processing Record 37 | Vaini
# Processing Record 38 | Hami
# Processing Record 39 | Turukhansk
# Processing Record 40 | Hilo
# Processing Record 41 | Upernavik
# Processing Record 42 | Yar-Sale
# Processing Record 43 | Bud
# Processing Record 44 | Talara
# Processing Record 45 | Georgetown
# City not found. Skipping...
# Processing Record 46 | Nikolskoye
# Processing Record 47 | Maceio
# Processing Record 48 | Lavrentiya
# Processing Record 49 | Half Moon Bay
# Processing Record 50 | Cape Town
# Processing Record 51 | Kruisfontein
# Processing Record 52 | Mount Isa
# Processing Record 53 | Ponta do Sol
# Processing Record 54 | Mount Gambier
# City not found. Skipping...
# Processing Record 55 | Karlskrona
# Processing Record 56 | Talnakh
# Processing Record 57 | El Alto
# Processing Record 58 | Muravlenko
# Processing Record 59 | Nisia Floresta
# Processing Record 60 | Plettenberg Bay
# Processing Record 61 | Tiksi
# Processing Record 62 | Buchanan
# Processing Record 63 | Wajid
# Processing Record 64 | Hobart
# Processing Record 65 | Humaita
# Processing Record 66 | Chapais
# Processing Record 67 | Qaanaaq
# Processing Record 68 | Khatanga
# Processing Record 69 | Husavik
# Processing Record 70 | Atuona
# Processing Record 71 | Pilikwe
# Processing Record 72 | College
# Processing Record 73 | Arraial do Cabo
# Processing Record 74 | Tuktoyaktuk
# Processing Record 75 | Kieta
# Processing Record 76 | Najran
# Processing Record 77 | Bethel
# Processing Record 78 | Port Alfred
# Processing Record 79 | Bauchi
# Processing Record 80 | Boundiali
# Processing Record 81 | Namibe
# Processing Record 82 | Owando
# Processing Record 83 | Bonfim
# Processing Record 84 | Kapaa
# Processing Record 85 | Saint-Philippe
# Processing Record 86 | Saint-Francois
# Processing Record 87 | Broome
# Processing Record 88 | Panguna
# Processing Record 89 | Rognedino
# Processing Record 90 | Batagay
# Processing Record 91 | Vestmannaeyjar
# Processing Record 92 | Birao
# Processing Record 93 | Kaitangata
# Processing Record 94 | Chuy
# Processing Record 95 | Lhokseumawe
# Processing Record 96 | Banjar
# Processing Record 97 | Bahia Honda
# Processing Record 98 | Rocha
# Processing Record 99 | Fairbanks
# Processing Record 100 | Pyaozerskiy
# City not found. Skipping...
# Processing Record 101 | Severo-Kurilsk
# Processing Record 102 | Lompoc
# Processing Record 103 | Hailar
# Processing Record 104 | Mindelo
# Processing Record 105 | Longyearbyen
# Processing Record 106 | Mar del Plata
# Processing Record 107 | Zalantun
# Processing Record 108 | Kamaishi
# Processing Record 109 | The Valley
# City not found. Skipping...
# Processing Record 110 | Zyryanka
# City not found. Skipping...
# Processing Record 111 | Faanui
# Processing Record 112 | Ulladulla
# Processing Record 113 | Henties Bay
# Processing Record 114 | Pangnirtung
# Processing Record 115 | Jamestown
# Processing Record 116 | Souillac
# Processing Record 117 | Alice Town
# City not found. Skipping...
# Processing Record 118 | Gold Coast
# Processing Record 119 | Bredasdorp
# Processing Record 120 | Pevek
# Processing Record 121 | Port Elizabeth
# Processing Record 122 | Bubaque
# Processing Record 123 | Palmer
# Processing Record 124 | Mayna
# Processing Record 125 | Victoria
# Processing Record 126 | Hibbing
# Processing Record 127 | Maria Aurora
# Processing Record 128 | Kudahuvadhoo
# Processing Record 129 | Butaritari
# Processing Record 130 | Buala
# Processing Record 131 | Juazeiro
# Processing Record 132 | Kavieng
# Processing Record 133 | East London
# Processing Record 134 | Ribeira Grande
# Processing Record 135 | Isangel
# Processing Record 136 | Noumea
# Processing Record 137 | Nelson Bay
# City not found. Skipping...
# Processing Record 138 | Leningradskiy
# Processing Record 139 | Leshukonskoye
# Processing Record 140 | Manaure
# Processing Record 141 | Robertsport
# Processing Record 142 | Saskylakh
# Processing Record 143 | Sistranda
# Processing Record 144 | Thompson
# Processing Record 145 | Vao
# Processing Record 146 | Shimoda
# Processing Record 147 | Sayyan
# Processing Record 148 | Ishigaki
# Processing Record 149 | Iwaki
# Processing Record 150 | Saldanha
# City not found. Skipping...
# Processing Record 151 | Shahi
# Processing Record 152 | Baykit
# Processing Record 153 | Luderitz
# Processing Record 154 | Kirkland Lake
# Processing Record 155 | La Canada Flintridge
# Processing Record 156 | Zhigansk
# Processing Record 157 | Acajutla
# Processing Record 158 | Pacific Grove
# Processing Record 159 | Axim
# Processing Record 160 | Eenhana
# Processing Record 161 | Naron
# Processing Record 162 | Constitucion
# Processing Record 163 | Kodiak
# Processing Record 164 | Nioro
# Processing Record 165 | Bridlington
# Processing Record 166 | Sur
# Processing Record 167 | Narsaq
# Processing Record 168 | Cheyenne
# Processing Record 169 | Ahuimanu
# Processing Record 170 | Delijan
# City not found. Skipping...
# Processing Record 171 | Saint-Michel-des-Saints
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 172 | Amsterdam
# Processing Record 173 | Mahebourg
# Processing Record 174 | Vardo
# Processing Record 175 | Sharkan
# Processing Record 176 | Salalah
# Processing Record 177 | Miandrivazo
# Processing Record 178 | Saint George
# Processing Record 179 | Hambantota
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 180 | Mundybash
# Processing Record 181 | Lengshuitan
# Processing Record 182 | Atasu
# Processing Record 183 | Mhlambanyatsi
# Processing Record 184 | Hwange
# Processing Record 185 | Ankang
# Processing Record 186 | Maracas
# Processing Record 187 | Sao Felix do Xingu
# Processing Record 188 | Yerbogachen
# Processing Record 189 | Aklavik
# Processing Record 190 | Grindavik
# Processing Record 191 | Trabzon
# Processing Record 192 | Fuji
# Processing Record 193 | Dzaoudzi
# Processing Record 194 | Dunedin
# Processing Record 195 | Fez
# Processing Record 196 | Suez
# Processing Record 197 | Buluang
# Processing Record 198 | Spasskoye
# Processing Record 199 | Acari
# Processing Record 200 | Betanzos
# City not found. Skipping...
# Processing Record 201 | Nizhniy Tsasuchey
# Processing Record 202 | Nouadhibou
# Processing Record 203 | Nome
# Processing Record 204 | Alofi
# Processing Record 205 | Sao Raimundo das Mangabeiras
# Processing Record 206 | Luis Correia
# Processing Record 207 | Esperance
# Processing Record 208 | Mogadishu
# Processing Record 209 | Mathbaria
# Processing Record 210 | Bilibino
# Processing Record 211 | Poli
# Processing Record 212 | Port Lincoln
# Processing Record 213 | Kerrobert
# Processing Record 214 | Beringovskiy
# Processing Record 215 | Saint-Pierre
# Processing Record 216 | Frontera
# Processing Record 217 | Akureyri
# Processing Record 218 | Puyang
# Processing Record 219 | Leh
# Processing Record 220 | Cazones
# Processing Record 221 | Paamiut
# Processing Record 222 | Hasaki
# Processing Record 223 | Arkansas City
# Processing Record 224 | Mehamn
# Processing Record 225 | Mahon
# Processing Record 226 | Ambulu
# Processing Record 227 | Tigzirt
# Processing Record 228 | Champerico
# Processing Record 229 | Seoul
# Processing Record 230 | San Cristobal
# Processing Record 231 | Tuatapere
# Processing Record 232 | Senneterre
# Processing Record 233 | Geraldton
# Processing Record 234 | Kloulklubed
# Processing Record 235 | Kidal
# City not found. Skipping...
# Processing Record 236 | Katsuura
# City not found. Skipping...
# Processing Record 237 | Mecca
# Processing Record 238 | Turayf
# Processing Record 239 | Cabo San Lucas
# Processing Record 240 | Clyde River
# Processing Record 241 | Yenagoa
# City not found. Skipping...
# Processing Record 242 | La Ronge
# Processing Record 243 | Carnarvon
# Processing Record 244 | Southbridge
# Processing Record 245 | Flinders
# Processing Record 246 | Atikokan
# Processing Record 247 | San Patricio
# Processing Record 248 | Adrar
# Processing Record 249 | Hovd
# Processing Record 250 | Berlevag
# Processing Record 251 | Nyurba
# Processing Record 252 | Sikonge
# Processing Record 253 | Doaba
# Processing Record 254 | Samarai
# Processing Record 255 | Luena
# Processing Record 256 | Norman Wells
# Processing Record 257 | Tokmak
# Processing Record 258 | Kamenka
# Processing Record 259 | Aasiaat
# Processing Record 260 | Elliot
# City not found. Skipping...
# Processing Record 261 | Cartagena
# Processing Record 262 | Tura
# Processing Record 263 | Ibotirama
# Processing Record 264 | Pisco
# Processing Record 265 | Comodoro Rivadavia
# Processing Record 266 | Kitimat
# Processing Record 267 | Ust-Tsilma
# Processing Record 268 | Benguela
# Processing Record 269 | Salima
# Processing Record 270 | Hualmay
# City not found. Skipping...
# Processing Record 271 | Dikson
# Processing Record 272 | Hofn
# Processing Record 273 | Celestun
# Processing Record 274 | Urengoy
# Processing Record 275 | Dingle
# Processing Record 276 | Les Cayes
# Processing Record 277 | Cherskiy
# Processing Record 278 | Ekibastuz
# Processing Record 279 | Saint Anthony
# Processing Record 280 | Klaksvik
# Processing Record 281 | Kizukuri
# Processing Record 282 | Chokurdakh
# Processing Record 283 | Luwuk
# Processing Record 284 | Joshimath
# Processing Record 285 | Damaturu
# Processing Record 286 | Conceicao do Araguaia
# Processing Record 287 | Elko
# Processing Record 288 | Valley City
# Processing Record 289 | Maniitsoq
# Processing Record 290 | Kailua
# Processing Record 291 | Moranbah
# Processing Record 292 | Tautira
# Processing Record 293 | Kargil
# Processing Record 294 | Alice Springs
# Processing Record 295 | Touros
# Processing Record 296 | Thoen
# Processing Record 297 | Lasa
# Processing Record 298 | Marawi
# Processing Record 299 | Laje
# Processing Record 300 | Egvekinot
# Processing Record 301 | Palaikastron
# Processing Record 302 | Zaranj
# Processing Record 303 | Viedma
# Processing Record 304 | Astara
# Processing Record 305 | Abha
# Processing Record 306 | Waitati
# Processing Record 307 | Ostrovnoy
# Processing Record 308 | Bondo
# Processing Record 309 | Sambava
# Processing Record 310 | Petropavlovsk-Kamchatskiy
# Processing Record 311 | Goderich
# Processing Record 312 | Eyl
# Processing Record 313 | Kazachinskoye
# Processing Record 314 | Volary
# Processing Record 315 | Bam
# Processing Record 316 | Torbay
# City not found. Skipping...
# Processing Record 317 | Puerto Rico
# Processing Record 318 | Manokwari
# Processing Record 319 | Hinton
# Processing Record 320 | North Bend
# Processing Record 321 | Vilhena
# Processing Record 322 | Aranos
# Processing Record 323 | Ancud
# Processing Record 324 | Tual
# Processing Record 325 | Cascais
# Processing Record 326 | Lufilufi
# Processing Record 327 | Ahipara
# Processing Record 328 | Orlik
# Processing Record 329 | Xingyi
# City not found. Skipping...
# Processing Record 330 | Ordzhonikidze
# Processing Record 331 | Zabol
# Processing Record 332 | Ust-Barguzin
# City not found. Skipping...
# Processing Record 333 | Juneau
# Processing Record 334 | Labuhan
# Processing Record 335 | Margate
# Processing Record 336 | Todos Santos
# Processing Record 337 | Nanakuli
# Processing Record 338 | Luancheng
# City not found. Skipping...
# Processing Record 339 | Jackson
# Processing Record 340 | Bangil
# Processing Record 341 | Kachiry
# Processing Record 342 | Hare Bay
# Processing Record 343 | Aksu
# Processing Record 344 | Porto Novo
# Processing Record 345 | Moree
# Processing Record 346 | Amga
# Processing Record 347 | Ewa Beach
# Processing Record 348 | Kapustin Yar
# Processing Record 349 | Huarmey
# Processing Record 350 | Kirakira
# Processing Record 351 | Port Blair
# Processing Record 352 | Pimentel
# Processing Record 353 | Komsomolskiy
# Processing Record 354 | Alberdi
# Processing Record 355 | Praya
# Processing Record 356 | Kahului
# Processing Record 357 | Tevriz
# Processing Record 358 | Makat
# Processing Record 359 | Elliot Lake
# Processing Record 360 | Lata
# Processing Record 361 | Wilmington
# Processing Record 362 | Carutapera
# Processing Record 363 | Hutchinson
# Processing Record 364 | Biak
# Processing Record 365 | Poya
# City not found. Skipping...
# Processing Record 366 | Rundu
# Processing Record 367 | Konya
# Processing Record 368 | Naze
# Processing Record 369 | Bandarbeyla
# Processing Record 370 | Rimbey
# Processing Record 371 | Imeni Poliny Osipenko
# Processing Record 372 | Lokoja
# Processing Record 373 | Nikolskiy
# Processing Record 374 | Forestville
# City not found. Skipping...
# Processing Record 375 | Matara
# Processing Record 376 | Sitka
# Processing Record 377 | Siguiri
# Processing Record 378 | Sobolevo
# Processing Record 379 | Chauk
# Processing Record 380 | Nilanga
# Processing Record 381 | Tabou
# Processing Record 382 | Phek
# Processing Record 383 | Amazar
# Processing Record 384 | Puerto El Triunfo
# Processing Record 385 | Kungurtug
# Processing Record 386 | Te Anau
# Processing Record 387 | Antofagasta
# Processing Record 388 | Durango
# Processing Record 389 | Mahibadhoo
# Processing Record 390 | Cidreira
# Processing Record 391 | Chickasha
# Processing Record 392 | Ipixuna
# Processing Record 393 | Mizdah
# Processing Record 394 | Kaya
# Processing Record 395 | Blucina
# Processing Record 396 | Zhumadian
# Processing Record 397 | Agadez
# City not found. Skipping...
# Processing Record 398 | Rajampet
# Processing Record 399 | Rabo de Peixe
# Processing Record 400 | Mangrol
# Processing Record 401 | Srednekolymsk
# Processing Record 402 | Lebu
# Processing Record 403 | Kendari
# Processing Record 404 | Poum
# Processing Record 405 | Aswan
# Processing Record 406 | Dunmore East
# Processing Record 407 | Uvinza
# Processing Record 408 | Nalut
# Processing Record 409 | Cortez
# Processing Record 410 | Sorong
# Processing Record 411 | Novaya Igirma
# Processing Record 412 | Mikumi
# Processing Record 413 | Neuquen
# Processing Record 414 | Vallenar
# Processing Record 415 | Dwarka
# Processing Record 416 | Ternate
# Processing Record 417 | Presidencia Roque Saenz Pena
# City not found. Skipping...
# Processing Record 418 | Tarnowskie Gory
# Processing Record 419 | Nongstoin
# Processing Record 420 | Jiuquan
# City not found. Skipping...
# Processing Record 421 | Hastings
# Processing Record 422 | Santa Isabel
# Processing Record 423 | Novyy Buh
# Processing Record 424 | Sorata
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 425 | Homer
# Processing Record 426 | Kapiri Mposhi
# Processing Record 427 | Vila Franca do Campo
# Processing Record 428 | Riobamba
# Processing Record 429 | Turan
# Processing Record 430 | Chicama
# Processing Record 431 | Qinhuangdao
# Processing Record 432 | Quatre Cocos
# Processing Record 433 | Thabazimbi
# Processing Record 434 | Xai-Xai
# Processing Record 435 | Pulsano
# Processing Record 436 | Tamandare
# Processing Record 437 | Ojiya
# Processing Record 438 | Camabatela
# Processing Record 439 | Logan
# Processing Record 440 | Belmonte
# Processing Record 441 | Mamallapuram
# City not found. Skipping...
# Processing Record 442 | Vuktyl
# Processing Record 443 | Warrington
# Processing Record 444 | Darhan
# City not found. Skipping...
# Processing Record 445 | Mildura
# Processing Record 446 | Tiruchchirappalli
# Processing Record 447 | Ankara
# Processing Record 448 | Kirensk
# Processing Record 449 | Mocuba
# City not found. Skipping...
# Processing Record 450 | Yulara
# Processing Record 451 | Isla Mujeres
# Processing Record 452 | Galbshtadt
# Processing Record 453 | Ponazyrevo
# City not found. Skipping...
# Processing Record 454 | Kharp
# Processing Record 455 | Arcata
# Processing Record 456 | Armizonskoye
# City not found. Skipping...
# Processing Record 457 | Mitsamiouli
# Processing Record 458 | Umm Kaddadah
# Processing Record 459 | Fortuna
# Processing Record 460 | Pundaguitan
# Processing Record 461 | Havre-Saint-Pierre
# Processing Record 462 | Muros
# Processing Record 463 | Hay River
# City not found. Skipping...
# Processing Record 464 | Puerto Carreno
# Processing Record 465 | Grand Junction
# Processing Record 466 | Zhangye
# Processing Record 467 | Vitim
# Processing Record 468 | Adeje
# Processing Record 469 | Jaynagar
# Processing Record 470 | Wewak
# Processing Record 471 | Obidos
# Processing Record 472 | Wagar
# Processing Record 473 | Louga
# City not found. Skipping...
# Processing Record 474 | Dudinka
# Processing Record 475 | Jurm
# Processing Record 476 | Qasigiannguit
# Processing Record 477 | Baoqing
# Processing Record 478 | Wellington
# Processing Record 479 | Cockburn Town
# Processing Record 480 | Ritchie
# Processing Record 481 | Port-Cartier
# Processing Record 482 | Port Hardy
# Processing Record 483 | Ashland
# Processing Record 484 | Grand Gaube
# Processing Record 485 | Arari
# Processing Record 486 | Sorland
# Processing Record 487 | Angoram
# City not found. Skipping...
# Processing Record 488 | Taoudenni
# Processing Record 489 | Namatanai
# Processing Record 490 | Ambon
# Processing Record 491 | Gondanglegi
# Processing Record 492 | Humboldt
# Processing Record 493 | Waipawa
# Processing Record 494 | San Lorenzo
# Processing Record 495 | Phulpur
# Processing Record 496 | Santander
# Processing Record 497 | Iqaluit
# Processing Record 498 | Milkovo
# Processing Record 499 | Youghal
# Processing Record 500 | Tazmalt
# Processing Record 501 | Lorengau
# Processing Record 502 | Vila Velha
# Processing Record 503 | Sidi Ali
# City not found. Skipping...
# Processing Record 504 | Shu
# Processing Record 505 | Wadena
# Processing Record 506 | Lieto
# Processing Record 507 | Martil
# Processing Record 508 | Motril
# Processing Record 509 | Gazanjyk
# City not found. Skipping...
# Processing Record 510 | Meulaboh
# Processing Record 511 | Dolores
# City not found. Skipping...
# Processing Record 512 | Oranjemund
# Processing Record 513 | Oussouye
# Processing Record 514 | Ayan
# Processing Record 515 | Slavonice
# Processing Record 516 | Saint Lawrence
# Processing Record 517 | Bobrovka
# Processing Record 518 | Lamar
# Processing Record 519 | Nuuk
# Processing Record 520 | Przhevalskoye
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 521 | Xining
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 522 | Standerton
# Processing Record 523 | Bontang
# Processing Record 524 | Lashio
# Processing Record 525 | Dakar
# Processing Record 526 | Teya
# Processing Record 527 | Izumo
# Processing Record 528 | Padang
# Processing Record 529 | Praia da Vitoria
# Processing Record 530 | Storslett
# Processing Record 531 | Treinta y Tres
# City not found. Skipping...
# Processing Record 532 | Bardstown
# Processing Record 533 | Pouembout
# Processing Record 534 | Palu
# Processing Record 535 | Jamame
# City not found. Skipping...
# Processing Record 536 | Fairlie
# Processing Record 537 | Truro
# Processing Record 538 | Naryan-Mar
# Processing Record 539 | Tias
# Processing Record 540 | Arica
# Processing Record 541 | Vostok
# Processing Record 542 | Gigmoto
# Processing Record 543 | Beeville
# Processing Record 544 | Shache
# Processing Record 545 | Bodden Town
# City not found. Skipping...
# Processing Record 546 | Miraflores
# Processing Record 547 | Ilulissat
# Processing Record 548 | Pumiao
# Processing Record 549 | Opuwo
# Processing Record 550 | Mandalgovi
# Processing Record 551 | Marsa Matruh
# City not found. Skipping...
# Processing Record 552 | Danville
# City not found. Skipping...
# City not found. Skipping...
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %%
# Convert Raw Data to DataFrame
# Export the city data into a .csv.
# Display the DataFrame

weather_dict = {
    "City": city_name,
    "Country": country,
    "Date": date,
    "Latitude": latitude,
    "Longitude": longitude,
    "Max Temperature": max_temperature,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed
}

weather_data = pd.DataFrame(weather_dict)
weather_data.count()
# Out:
# City               552
# Country            552
# Date               552
# Latitude           552
# Longitude          552
# Max Temperature    552
# Humidity           552
# Cloudiness         552
# Wind Speed         552
# dtype: int64

# %%
City          547
Cloudiness    547
Country       547
Date          547
Humidity      547
Lat           547
Lng           547
Max Temp      547
Wind Speed    547
dtype: int64
# Out:
#   File "<ipython-input-13-f0e4dca96119>", line 1
#     City          547
#                     ^
# SyntaxError: invalid syntax

# %%
# Show table

weather_data.head()

# %%
# Export to CSV file
weather_data.to_csv("./Data/weather_data.csv")

# %%
#  Latitude vs. Temperature Plot
plt.scatter(weather_data["Latitude"], weather_data["Max Temperature"], facecolors="red", marker="o", edgecolor="black")

# Incorporate Other Graph Properties
plt.title("City Latitude vs. Max Temperature (02/01/2019)")
plt.ylabel("Max Temperature (°F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save Figure
plt.savefig("./Data/City_Latitude_vs_Max_Temperature.png")

# Show Plot
plt.show()

# %%
#  Latitude vs. Humidity Plot
plt.scatter(weather_data["Latitude"], weather_data["Humidity"], facecolors="green", marker="o", edgecolor="black")
# Incorporate Other Graph Properties
plt.title("City Latitude vs. Humidity (02/01/2019)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save Figure
plt.savefig("./Data/City_Latitude_vs_Humidity.png")

# Show Plot
plt.show()

# %%
#  Latitude vs. Cloudiness Plot
plt.scatter(weather_data["Latitude"], weather_data["Cloudiness"], facecolors="blue", marker="o", edgecolor="black")

# Incorporate Other Graph Properties
plt.title("City Latitude vs. Cloudiness (02/01/2019)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save Figure
plt.savefig("./Data/City_Latitude_vs_Cloudiness.png")

# Show Plot
plt.show()

# %%
#  Latitude vs. Wind Speed Plot
plt.scatter(weather_data["Latitude"], weather_data["Wind Speed"], facecolors="yellow", marker="o", edgecolor="black")

# Incorporate Other Graph Properties
plt.title("City Latitude vs. Wind Speed (02/01/2019)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save Figure
plt.savefig("./Data/City_Latitude_vs_Wind_Speed.png")

# Show Plot
plt.show()
